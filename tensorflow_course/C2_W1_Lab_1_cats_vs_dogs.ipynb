# %% [markdown]
# <a href="https://colab.research.google.com/github/https-deeplearning-ai/tensorflow-1-public/blob/master/C2/W1/ungraded_lab/C2_W1_Lab_1_cats_vs_dogs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ungraded Lab: Using more sophisticated images with Convolutional Neural Networks
#
# In Course 1 of this specialization, you saw how to use a CNN to make your recognition of computer generated images of horses and humans more efficient. In this lesson, you'll take that to the next level: building a model to classify real images of cats and dogs. Like the horses and humans dataset, real-world images also come in different shapes, aspect ratios, etc. and you will need to take this into account when preparing your data.
#
# In this lab, you will first review how to build CNNs, prepare your data with `ImageDataGenerator` and examine your results. You'll follow these steps:
#
# 1.   Explore the example data of `Dogs vs. Cats`
# 2.   Build and train a neural network to classify between the two pets
# 3.   Evaluate the training and validation accuracy
#
# You will build upon your results here in the next labs so you can improve it, particularly in avoiding overfitting. Let's begin!

# %% [markdown]
# **IMPORTANT NOTE:** This notebook is designed to run as a Colab. Running it on your local machine might result in some of the code blocks throwing errors.

# %% [markdown]
# ## Download and Inspect the Dataset
#
# You will start by downloading the dataset. This is a `.zip` of 2,000 JPG pictures of cats and dogs. It is a subset of the ["Dogs vs. Cats" dataset](https://www.kaggle.com/c/dogs-vs-cats/data) available on Kaggle, which contains 25,000 images. You will only use 2,000 of the full dataset to decrease training time for educational purposes.

# %%
# !wget --no-check-certificate https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip

# %% [markdown]
# You will then extract it to the current directory.

# %%
#import zipfile

# Unzip the archive
#local_zip = './cats_and_dogs_filtered.zip'
#zip_ref = zipfile.ZipFile(local_zip, 'r')
#zip_ref.extractall()

#zip_ref.close()

# %% [markdown]
# The contents of the .zip are extracted to the base directory `./cats_and_dogs_filtered`, which contains `train` and `validation` subdirectories for the training and validation datasets (you can ignore `vectorize.py` in the output in the next cell).
#
# If you recall, the **training set** is the data that is used to tell the neural network model that 'this is what a cat looks like' and 'this is what a dog looks like'. The **validation set** is images of cats and dogs that the neural network will not see as part of the training. You can use this to test how well or how badly it does in evaluating if an image contains a cat or a dog. (See the [Machine Learning Crash Course](https://developers.google.com/machine-learning/crash-course/validation/check-your-intuition) if you want a refresher on training, validation, and test sets.)
#
# These subdirectories in turn each contain `cats` and `dogs` subdirectories.

# %%
import os

base_dir = 'cats_and_dogs_filtered'

print("Contents of base directory:")
print(os.listdir(base_dir))

print("\nContents of train directory:")
print(os.listdir(f'{base_dir}/train'))

print("\nContents of validation directory:")
print(os.listdir(f'{base_dir}/validation'))
# Out:
# Contents of base directory:
# ['vectorize.py', 'validation', 'train']
#
# Contents of train directory:
# ['cats', 'dogs']
#
# Contents of validation directory:
# ['cats', 'dogs']

# %% [markdown]
# You can assign each of these directories to a variable so you can use it later.

# %%
import os

train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# Directory with training cat/dog pictures
train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')

# Directory with validation cat/dog pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

# %% [markdown]
# Now see what the filenames look like in the `cats` and `dogs` `train` directories (file naming conventions are the same in the `validation` directory):

# %%
train_cat_fnames = os.listdir( train_cats_dir )
train_dog_fnames = os.listdir( train_dogs_dir )

print(train_cat_fnames[:10])
print(train_dog_fnames[:10])
# Out:
# ['cat.284.jpg', 'cat.670.jpg', 'cat.974.jpg', 'cat.485.jpg', 'cat.481.jpg', 'cat.602.jpg', 'cat.945.jpg', 'cat.454.jpg', 'cat.744.jpg', 'cat.683.jpg']
# ['dog.750.jpg', 'dog.297.jpg', 'dog.698.jpg', 'dog.989.jpg', 'dog.68.jpg', 'dog.531.jpg', 'dog.785.jpg', 'dog.356.jpg', 'dog.279.jpg', 'dog.829.jpg']

# %% [markdown]
# Let's find out the total number of cat and dog images in the `train` and `validation` directories:

# %%
print('total training cat images :', len(os.listdir(      train_cats_dir ) ))
print('total training dog images :', len(os.listdir(      train_dogs_dir ) ))

print('total validation cat images :', len(os.listdir( validation_cats_dir ) ))
print('total validation dog images :', len(os.listdir( validation_dogs_dir ) ))
# Out:
# total training cat images : 1000
# total training dog images : 1000
# total validation cat images : 500
# total validation dog images : 500

# %% [markdown]
# For both cats and dogs, you have 1,000 training images and 500 validation images.
#
# Now take a look at a few pictures to get a better sense of what the cat and dog datasets look like. First, configure the `matplotlib` parameters:

# %%
# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 4
ncols = 4

pic_index = 0 # Index for iterating over images

# %% [markdown]
# Now, display a batch of 8 cat and 8 dog pictures. You can re-run the cell to see a fresh batch each time:

# %%
# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols*4, nrows*4)

pic_index+=8

next_cat_pix = [os.path.join(train_cats_dir, fname) 
                for fname in train_cat_fnames[ pic_index-8:pic_index] 
               ]

next_dog_pix = [os.path.join(train_dogs_dir, fname) 
                for fname in train_dog_fnames[ pic_index-8:pic_index]
               ]

for i, img_path in enumerate(next_cat_pix+next_dog_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %% [markdown]
# It may not be obvious from looking at the images in this grid but an important note here is that these images come in all shapes and sizes (just like the 'horses or humans' dataset). So before training a neural network with them, you'll need to tweak the images. You'll see that in the next sections.

# %% [markdown]
# ## Building a Small Model from Scratch to get to ~72% Accuracy
#
# To train a neural network to handle the images, you'll need them to be in a uniform size. You will choose 150x150 pixels for this, and you'll see the code that preprocesses the images to that shape shortly.
#
# You can define the model by importing Tensorflow and using the Keras API. Here is the entire code first then the discussion comes after. This is very similar to the models you have built in Course 1.

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 150x150 with 3 bytes color
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2), 
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), 
    tf.keras.layers.MaxPooling2D(2,2),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(), 
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'), 
    # Only 1 output neuron. It will contain a value from 0-1 where 0 for 1 class ('cats') and 1 for the other ('dogs')
    tf.keras.layers.Dense(1, activation='sigmoid')  
])
# Out:
# 2022-07-28 21:05:07.031599: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-28 21:05:07.035327: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-28 21:05:07.035468: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-28 21:05:07.035767: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-28 21:05:07.036531: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-28 21:05:07.036661: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-28 21:05:07.036775: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-28 21:05:07.342998: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-28 21:05:07.343152: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-28 21:05:07.343272: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-28 21:05:07.343373: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5720 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:2a:00.0, compute capability: 8.6

# %% [markdown]
# You defined a `Sequential` layer as before, adding some convolutional layers first. Note the `input_shape` parameter this time. Here is where you put the `150x150` size and `3` for the color depth because you have colored images. You then add a couple of convolutional layers and flatten the final result to feed into the densely connected layers.

# %% [markdown]
# Note that because you are facing a two-class classification problem, i.e. a *binary classification problem*, you will end the network with a [*sigmoid* activation](https://wikipedia.org/wiki/Sigmoid_function). The output of the network will be a single scalar between `0` and `1`, encoding the probability that the current image is class `1` (as opposed to class `0`).

# %% [markdown]
# You can review the architecture of the network with the `model.summary()` method:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 18496)             0
#
#  dense (Dense)               (None, 512)               9470464
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The `output_shape` column shows how the size of your feature map evolves in each successive layer. The convolution operation removes the outermost pixels from the original dimensions, and each pooling layer halves it.

# %% [markdown]
# Next, you'll configure the specifications for model training. You will train our model with the `binary_crossentropy` loss, because it's a binary classification problem and your final activation is a sigmoid. We will use the `rmsprop` optimizer with a learning rate of `0.001`. During training, you will want to monitor classification accuracy.
#
# **NOTE**: In this case, using the [RMSprop optimization algorithm](https://wikipedia.org/wiki/Stochastic_gradient_descent#RMSProp) is preferable to [stochastic gradient descent](https://developers.google.com/machine-learning/glossary/#SGD) (SGD), because RMSprop automates learning-rate tuning for us. (Other optimizers, such as [Adam](https://wikipedia.org/wiki/Stochastic_gradient_descent#Adam) and [Adagrad](https://developers.google.com/machine-learning/glossary/#AdaGrad), also automatically adapt the learning rate during training, and would work equally well here.)

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(optimizer=RMSprop(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics = ['accuracy'])

# %% [markdown]
# ### Data Preprocessing
#
# Next step is to set up the data generators that will read pictures in the source folders, convert them to `float32` tensors, and feed them (with their labels) to the model. You'll have one generator for the training images and one for the validation images. These generators will yield batches of images of size 150x150 and their labels (binary).
#
# As you may already know, data that goes into neural networks should usually be normalized in some way to make it more amenable to processing by the network (i.e. It is uncommon to feed raw pixels into a ConvNet.) In this case, you will preprocess the images by normalizing the pixel values to be in the `[0, 1]` range (originally all values are in the `[0, 255]` range).
#
# In Keras, this can be done via the `keras.preprocessing.image.ImageDataGenerator` class using the `rescale` parameter. This `ImageDataGenerator` class allows you to instantiate generators of augmented image batches (and their labels) via `.flow(data, labels)` or `.flow_from_directory(directory)`.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# All images will be rescaled by 1./255.
train_datagen = ImageDataGenerator( rescale = 1.0/255. )
test_datagen  = ImageDataGenerator( rescale = 1.0/255. )

# --------------------
# Flow training images in batches of 20 using train_datagen generator
# --------------------
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=20,
                                                    class_mode='binary',
                                                    target_size=(150, 150))     
# --------------------
# Flow validation images in batches of 20 using test_datagen generator
# --------------------
validation_generator =  test_datagen.flow_from_directory(validation_dir,
                                                         batch_size=20,
                                                         class_mode  = 'binary',
                                                         target_size = (150, 150))
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# ### Training
# You will now train on all 2,000 images available, for 15 epochs, and monitor the accuracy as well on the 1,000 images in the validation set.
#
# Do note the values per epoch.
#
# You'll see 4 values per epoch -- Loss, Accuracy, Validation Loss and Validation Accuracy.
#
# The `loss` and `accuracy` are great indicators of progress in training. `loss` measures the current model prediction against the known labels, calculating the result. `accuracy`, on the other hand, is the portion of correct guesses.

# %%
history = model.fit(
            train_generator,
            epochs=15,
            validation_data=validation_generator,
            verbose=2
            )
# Out:
# Epoch 1/15
# 2022-07-28 21:05:08.476841: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8401
# 2022-07-28 21:05:09.256752: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-07-28 21:05:09.342167: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 100/100 - 4s - loss: 0.8646 - accuracy: 0.5385 - val_loss: 0.6474 - val_accuracy: 0.6710 - 4s/epoch - 44ms/step
# Epoch 2/15
# 100/100 - 2s - loss: 0.6467 - accuracy: 0.6515 - val_loss: 0.6790 - val_accuracy: 0.5970 - 2s/epoch - 23ms/step
# Epoch 3/15
# 100/100 - 2s - loss: 0.5618 - accuracy: 0.7200 - val_loss: 1.1916 - val_accuracy: 0.5170 - 2s/epoch - 22ms/step
# Epoch 4/15
# 100/100 - 2s - loss: 0.5021 - accuracy: 0.7590 - val_loss: 0.8835 - val_accuracy: 0.6010 - 2s/epoch - 22ms/step
# Epoch 5/15
# 100/100 - 2s - loss: 0.4101 - accuracy: 0.8120 - val_loss: 0.6603 - val_accuracy: 0.7190 - 2s/epoch - 23ms/step
# Epoch 6/15
# 100/100 - 2s - loss: 0.3137 - accuracy: 0.8545 - val_loss: 0.6612 - val_accuracy: 0.7180 - 2s/epoch - 22ms/step
# Epoch 7/15
# 100/100 - 2s - loss: 0.2396 - accuracy: 0.9020 - val_loss: 0.7404 - val_accuracy: 0.7130 - 2s/epoch - 22ms/step
# Epoch 8/15
# 100/100 - 2s - loss: 0.1582 - accuracy: 0.9360 - val_loss: 0.9996 - val_accuracy: 0.7090 - 2s/epoch - 22ms/step
# Epoch 9/15
# 100/100 - 2s - loss: 0.1139 - accuracy: 0.9610 - val_loss: 1.6030 - val_accuracy: 0.6830 - 2s/epoch - 23ms/step
# Epoch 10/15
# 100/100 - 2s - loss: 0.0962 - accuracy: 0.9715 - val_loss: 1.0775 - val_accuracy: 0.7220 - 2s/epoch - 22ms/step
# Epoch 11/15
# 100/100 - 2s - loss: 0.0651 - accuracy: 0.9800 - val_loss: 1.3564 - val_accuracy: 0.6900 - 2s/epoch - 22ms/step
# Epoch 12/15
# 100/100 - 2s - loss: 0.0708 - accuracy: 0.9800 - val_loss: 1.7778 - val_accuracy: 0.6900 - 2s/epoch - 22ms/step
# Epoch 13/15
# 100/100 - 2s - loss: 0.0291 - accuracy: 0.9920 - val_loss: 1.6580 - val_accuracy: 0.6980 - 2s/epoch - 23ms/step
# Epoch 14/15
# 100/100 - 2s - loss: 0.0466 - accuracy: 0.9850 - val_loss: 1.7494 - val_accuracy: 0.7060 - 2s/epoch - 22ms/step
# Epoch 15/15
# 100/100 - 2s - loss: 0.0476 - accuracy: 0.9890 - val_loss: 1.9394 - val_accuracy: 0.7150 - 2s/epoch - 23ms/step

# %% [markdown]
# ### Model Prediction
#
# Now take a look at actually running a prediction using the model. This code will allow you to choose 1 or more files from your file system, upload them, and run them through the model, giving an indication of whether the object is a cat or a dog.
#
# **Important Note:** Due to some compatibility issues, the following code block will result in an error after you select the images(s) to upload if you are running this notebook as a `Colab` on the `Safari` browser. For all other browsers, continue with the next code block and ignore the next one after it.
#
# _For Safari users: please comment out or skip the code block below, uncomment the next code block and run it._

# %% [raw]
# ## CODE BLOCK FOR NON-SAFARI BROWSERS
# ## SAFARI USERS: PLEASE SKIP THIS BLOCK AND RUN THE NEXT ONE INSTEAD
#
# import numpy as np
#
# from google.colab import files
# from keras.preprocessing import image
#
# uploaded=files.upload()
#
# for fn in uploaded.keys():
#
#   # predicting images
#   path='/content/' + fn
#   img=image.load_img(path, target_size=(150, 150))
#
#   x=image.img_to_array(img)
#   x /= 255
#   x=np.expand_dims(x, axis=0)
#   images = np.vstack([x])
#
#   classes = model.predict(images, batch_size=10)
#
#   print(classes[0])
#
#   if classes[0]>0.5:
#     print(fn + " is a dog")
#   else:
#     print(fn + " is a cat")

# %% [markdown]
# `Safari` users will need to upload the images(s) manually in their workspace. Please follow the instructions, uncomment the code block below and run it.
#
# Instructions on how to upload image(s) manually in a Colab:
#
# 1. Select the `folder` icon on the left `menu bar`.
# 2. Click on the `folder with an arrow pointing upwards` named `..`
# 3. Click on the `folder` named `tmp`.
# 4. Inside of the `tmp` folder, `create a new folder` called `images`. You'll see the `New folder` option by clicking the `3 vertical dots` menu button next to the `tmp` folder.
# 5. Inside of the new `images` folder, upload an image(s) of your choice, preferably of either a cat or a dog. Drag and drop the images(s) on top of the `images` folder.
# 6. Uncomment and run the code block below.

# %%
# # CODE BLOCK FOR SAFARI USERS

import numpy as np
from tensorflow.keras.preprocessing import image
import os

#images = os.listdir("/tmp/images")
images = os.listdir( validation_cats_dir )

#print(images)

for i in images:
    print()
# predicting images
    path =  os.path.join(validation_cats_dir, i)
    print(path)
    img = image.load_img(path, target_size=(150, 150))
    x = image.img_to_array(img)
    x /= 255
    x = np.expand_dims(x, axis=0)

    images = np.vstack([x])
    classes = model.predict(images, batch_size=10)
    print(classes[0])
    if classes[0]>0.5:
        print(i + " is a dog")
    else:
        print(i + " is a cat")
# Out:
# cats_and_dogs_filtered/validation/cats/cat.2490.jpg
# 1/1 [==============================] - 0s 88ms/step
# [4.251567e-13]
# cat.2490.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2144.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00033247]
# cat.2144.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2066.jpg
# 1/1 [==============================] - 0s 11ms/step
# [7.1872546e-06]
# cat.2066.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2169.jpg
# 1/1 [==============================] - 0s 10ms/step
# [1.1967289e-05]
# cat.2169.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2086.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00025038]
# cat.2086.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2398.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.8180751]
# cat.2398.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2099.jpg
# 1/1 [==============================] - 0s 11ms/step
# [6.40324e-05]
# cat.2099.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2360.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00054362]
# cat.2360.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2362.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.84222907]
# cat.2362.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2133.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00015743]
# cat.2133.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2131.jpg
# 1/1 [==============================] - 0s 11ms/step
# [2.392483e-07]
# cat.2131.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2082.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.08081947]
# cat.2082.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2400.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.01795227]
# cat.2400.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2216.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.98331016]
# cat.2216.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2422.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.51149863]
# cat.2422.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2014.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.03087603]
# cat.2014.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2335.jpg
# 1/1 [==============================] - 0s 11ms/step
# [7.8636967e-13]
# cat.2335.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2457.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.]
# cat.2457.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2389.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.74073744]
# cat.2389.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2149.jpg
# 1/1 [==============================] - 0s 11ms/step
# [9.569836e-10]
# cat.2149.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2201.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.92427284]
# cat.2201.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2197.jpg
# 1/1 [==============================] - 0s 11ms/step
# [5.8237026e-15]
# cat.2197.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2093.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.6907051e-09]
# cat.2093.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2214.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.99878937]
# cat.2214.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2450.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00016049]
# cat.2450.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2373.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.03911696]
# cat.2373.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2444.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00021991]
# cat.2444.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2343.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.18627967]
# cat.2343.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2349.jpg
# 1/1 [==============================] - 0s 10ms/step
# [7.818979e-09]
# cat.2349.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2368.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.9996158]
# cat.2368.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2204.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.14636259]
# cat.2204.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2026.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.8944251]
# cat.2026.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2453.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00263601]
# cat.2453.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2284.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.00028001]
# cat.2284.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2379.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.88372505]
# cat.2379.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2184.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.00150199]
# cat.2184.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2314.jpg
# 1/1 [==============================] - 0s 10ms/step
# [4.6412435e-05]
# cat.2314.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2046.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.0008729]
# cat.2046.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2172.jpg
# 1/1 [==============================] - 0s 10ms/step
# [1.5889282e-09]
# cat.2172.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2395.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.00558664]
# cat.2395.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2243.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.06618411]
# cat.2243.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2222.jpg
# 1/1 [==============================] - 0s 10ms/step
# [5.9890364e-11]
# cat.2222.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2100.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00021237]
# cat.2100.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2351.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00099431]
# cat.2351.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2211.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.99994695]
# cat.2211.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2039.jpg
# 1/1 [==============================] - 0s 11ms/step
# [4.7455746e-08]
# cat.2039.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2032.jpg
# 1/1 [==============================] - 0s 11ms/step
# [4.944717e-08]
# cat.2032.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2470.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.8216577e-05]
# cat.2470.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2241.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.02388272]
# cat.2241.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2015.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00066938]
# cat.2015.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2030.jpg
# 1/1 [==============================] - 0s 11ms/step
# [9.337471e-06]
# cat.2030.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2415.jpg
# 1/1 [==============================] - 0s 11ms/step
# [2.7536413e-07]
# cat.2415.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2371.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00038195]
# cat.2371.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2391.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.99941874]
# cat.2391.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2108.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00300782]
# cat.2108.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2346.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.91290957]
# cat.2346.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2098.jpg
# 1/1 [==============================] - 0s 11ms/step
# [7.0900515e-11]
# cat.2098.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2270.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.23699862]
# cat.2270.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2052.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00291568]
# cat.2052.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2248.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.00417453]
# cat.2248.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2205.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.9999795]
# cat.2205.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2069.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.00888102]
# cat.2069.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2091.jpg
# 1/1 [==============================] - 0s 11ms/step
# [3.1494823e-05]
# cat.2091.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2352.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.05533487]
# cat.2352.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2446.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.00601262]
# cat.2446.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2164.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.40513054]
# cat.2164.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2390.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.00273115]
# cat.2390.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2425.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.01148218]
# cat.2425.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2340.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.99979705]
# cat.2340.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2154.jpg
# 1/1 [==============================] - 0s 11ms/step
# [6.1977e-07]
# cat.2154.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2163.jpg
# 1/1 [==============================] - 0s 10ms/step
# [1.2108239e-05]
# cat.2163.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2058.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.992695]
# cat.2058.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2022.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.8833254e-05]
# cat.2022.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2080.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.5732805]
# cat.2080.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2481.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.9701616e-08]
# cat.2481.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2102.jpg
# 1/1 [==============================] - 0s 11ms/step
# [6.4578376e-06]
# cat.2102.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2106.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.06967445]
# cat.2106.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2420.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.99737704]
# cat.2420.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2448.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.99484044]
# cat.2448.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2000.jpg
# 1/1 [==============================] - 0s 11ms/step
# [5.6552203e-06]
# cat.2000.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2345.jpg
# 1/1 [==============================] - 0s 10ms/step
# [5.4319867e-18]
# cat.2345.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2324.jpg
# 1/1 [==============================] - 0s 10ms/step
# [8.8090616e-08]
# cat.2324.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2021.jpg
# 1/1 [==============================] - 0s 10ms/step
# [1.992854e-11]
# cat.2021.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2059.jpg
# 1/1 [==============================] - 0s 11ms/step
# [2.0972338e-06]
# cat.2059.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2170.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.00627912]
# cat.2170.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2228.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.62859654]
# cat.2228.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2075.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00714983]
# cat.2075.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2488.jpg
# 1/1 [==============================] - 0s 12ms/step
# [0.4898502]
# cat.2488.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2392.jpg
# 1/1 [==============================] - 0s 11ms/step
# [2.318105e-06]
# cat.2392.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2405.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.00022974]
# cat.2405.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2009.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.01887325]
# cat.2009.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2078.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.99991524]
# cat.2078.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2372.jpg
# 1/1 [==============================] - 0s 10ms/step
# [3.0973923e-10]
# cat.2372.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2295.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.4679974]
# cat.2295.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2271.jpg
# 1/1 [==============================] - 0s 11ms/step
# [3.2702037e-08]
# cat.2271.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2127.jpg
# 1/1 [==============================] - 0s 10ms/step
# [2.4589415e-06]
# cat.2127.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2374.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.98376036]
# cat.2374.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2258.jpg
# 1/1 [==============================] - 0s 10ms/step
# [7.4242074e-05]
# cat.2258.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2288.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.00275545]
# cat.2288.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2338.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.0795372]
# cat.2338.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2158.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.01698794]
# cat.2158.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2468.jpg
# 1/1 [==============================] - 0s 10ms/step
# [9.763766e-07]
# cat.2468.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2096.jpg
# 1/1 [==============================] - 0s 10ms/step
# [1.1971853e-06]
# cat.2096.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2031.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.7265784e-06]
# cat.2031.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2367.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.01559776]
# cat.2367.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2190.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.8471505]
# cat.2190.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2145.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.12317921]
# cat.2145.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2159.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.]
# cat.2159.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2281.jpg
# 1/1 [==============================] - 0s 10ms/step
# [3.013871e-12]
# cat.2281.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2063.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.99979967]
# cat.2063.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2285.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.29301345]
# cat.2285.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2460.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.03229884]
# cat.2460.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2195.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.99999964]
# cat.2195.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2489.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.02010003]
# cat.2489.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2033.jpg
# 1/1 [==============================] - 0s 11ms/step
# [6.5878294e-07]
# cat.2033.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2177.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.3301521]
# cat.2177.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2185.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.03426275]
# cat.2185.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2152.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.99917895]
# cat.2152.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2153.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.3491085]
# cat.2153.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2029.jpg
# 1/1 [==============================] - 0s 11ms/step
# [3.6885595e-09]
# cat.2029.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2496.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.05147086]
# cat.2496.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2231.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00641661]
# cat.2231.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2397.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.99151444]
# cat.2397.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2265.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.13197312]
# cat.2265.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2136.jpg
# 1/1 [==============================] - 0s 11ms/step
# [2.76327e-11]
# cat.2136.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2235.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.9978508]
# cat.2235.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2017.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.9747557e-07]
# cat.2017.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2283.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.98403394]
# cat.2283.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2193.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.12229934]
# cat.2193.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2262.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.9584874]
# cat.2262.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2485.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.6537429]
# cat.2485.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2277.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.0106649e-08]
# cat.2277.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2192.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.775316e-15]
# cat.2192.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2394.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.0465175]
# cat.2394.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2239.jpg
# 1/1 [==============================] - 0s 11ms/step
# [6.7889357e-16]
# cat.2239.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2008.jpg
# 1/1 [==============================] - 0s 11ms/step
# [3.8359217e-06]
# cat.2008.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2176.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.99999607]
# cat.2176.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2260.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.8492726]
# cat.2260.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2494.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.12099767]
# cat.2494.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2157.jpg
# 1/1 [==============================] - 0s 11ms/step
# [7.174273e-14]
# cat.2157.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2387.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.]
# cat.2387.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2286.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.08576449]
# cat.2286.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2062.jpg
# 1/1 [==============================] - 0s 11ms/step
# [8.143689e-05]
# cat.2062.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2359.jpg
# 1/1 [==============================] - 0s 11ms/step
# [9.240057e-06]
# cat.2359.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2167.jpg
# 1/1 [==============================] - 0s 11ms/step
# [8.6772054e-08]
# cat.2167.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2317.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.99997413]
# cat.2317.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2129.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00022441]
# cat.2129.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2479.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.10627665]
# cat.2479.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2212.jpg
# 1/1 [==============================] - 0s 11ms/step
# [4.15209e-13]
# cat.2212.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2105.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.21083895e-05]
# cat.2105.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2469.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00017688]
# cat.2469.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2116.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.0001882]
# cat.2116.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2081.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.8058667e-13]
# cat.2081.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2431.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.94194615]
# cat.2431.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2092.jpg
# 1/1 [==============================] - 0s 11ms/step
# [2.9296876e-07]
# cat.2092.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2495.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.44644013]
# cat.2495.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2077.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00566125]
# cat.2077.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2166.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.]
# cat.2166.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2363.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.9546951]
# cat.2363.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2141.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.31617036]
# cat.2141.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2318.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00103423]
# cat.2318.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2111.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.86192566]
# cat.2111.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2344.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.45007095]
# cat.2344.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2319.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00285779]
# cat.2319.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2484.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.27304035]
# cat.2484.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2493.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.9999976]
# cat.2493.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2035.jpg
# 1/1 [==============================] - 0s 11ms/step
# [6.8597774e-07]
# cat.2035.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2094.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.9986657]
# cat.2094.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2492.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.07974647]
# cat.2492.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2208.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.99701524]
# cat.2208.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2341.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.9998958]
# cat.2341.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2419.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.8584464]
# cat.2419.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2056.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.9506707]
# cat.2056.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2377.jpg
# 1/1 [==============================] - 0s 11ms/step
# [2.9583036e-05]
# cat.2377.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2187.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00651685]
# cat.2187.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2451.jpg
# 1/1 [==============================] - 0s 11ms/step
# [4.673611e-06]
# cat.2451.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2499.jpg
# 1/1 [==============================] - 0s 11ms/step
# [6.8916916e-07]
# cat.2499.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2350.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.999933]
# cat.2350.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2126.jpg
# 1/1 [==============================] - 0s 11ms/step
# [9.647616e-25]
# cat.2126.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2336.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.94605154]
# cat.2336.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2189.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00819697]
# cat.2189.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2276.jpg
# 1/1 [==============================] - 0s 11ms/step
# [5.213167e-12]
# cat.2276.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2042.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.99361926]
# cat.2042.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2036.jpg
# 1/1 [==============================] - 0s 10ms/step
# [5.6084044e-11]
# cat.2036.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2018.jpg
# 1/1 [==============================] - 0s 11ms/step
# [2.7744443e-07]
# cat.2018.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2461.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.98107636]
# cat.2461.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2217.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.8973777e-05]
# cat.2217.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2427.jpg
# 1/1 [==============================] - 0s 11ms/step
# [7.800318e-05]
# cat.2427.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2339.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00137517]
# cat.2339.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2065.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.20874707]
# cat.2065.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2332.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.9997658]
# cat.2332.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2278.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.05147558]
# cat.2278.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2002.jpg
# 1/1 [==============================] - 0s 11ms/step
# [5.5348077e-09]
# cat.2002.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2375.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.2852463e-06]
# cat.2375.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2044.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.99998784]
# cat.2044.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2143.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.06831785]
# cat.2143.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2302.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.7114274e-06]
# cat.2302.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2028.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.47819012]
# cat.2028.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2274.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00103819]
# cat.2274.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2256.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.9670921]
# cat.2256.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2327.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.99928904]
# cat.2327.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2342.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.0202928]
# cat.2342.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2429.jpg
# 1/1 [==============================] - 0s 11ms/step
# [2.0049721e-07]
# cat.2429.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2115.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.9269166e-09]
# cat.2115.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2043.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00148186]
# cat.2043.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2202.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00017861]
# cat.2202.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2138.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00019203]
# cat.2138.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2023.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.9257996e-05]
# cat.2023.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2162.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.2970837]
# cat.2162.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2402.jpg
# 1/1 [==============================] - 0s 11ms/step
# [3.928679e-07]
# cat.2402.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2267.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00153437]
# cat.2267.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2020.jpg
# 1/1 [==============================] - 0s 11ms/step
# [9.623667e-05]
# cat.2020.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2257.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00130103]
# cat.2257.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2439.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.4208092]
# cat.2439.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2040.jpg
# 1/1 [==============================] - 0s 10ms/step
# [2.530855e-05]
# cat.2040.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2165.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.2569863]
# cat.2165.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2097.jpg
# 1/1 [==============================] - 0s 13ms/step
# [2.1155117e-06]
# cat.2097.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2207.jpg
# 1/1 [==============================] - 0s 11ms/step
# [3.1928965e-05]
# cat.2207.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2355.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.0585123e-06]
# cat.2355.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2426.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00043986]
# cat.2426.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2118.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.02067719]
# cat.2118.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2060.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.02510597]
# cat.2060.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2050.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00596712]
# cat.2050.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2309.jpg
# 1/1 [==============================] - 0s 11ms/step
# [4.27712e-06]
# cat.2309.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2466.jpg
# 1/1 [==============================] - 0s 11ms/step
# [8.0071605e-10]
# cat.2466.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2179.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.9905724]
# cat.2179.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2103.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.12178659]
# cat.2103.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2037.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.2583404]
# cat.2037.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2365.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.01021542]
# cat.2365.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2388.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.9999832]
# cat.2388.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2173.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00042769]
# cat.2173.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2306.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00764217]
# cat.2306.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2449.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.10447245e-05]
# cat.2449.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2473.jpg
# 1/1 [==============================] - 0s 11ms/step
# [3.79553e-07]
# cat.2473.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2198.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00091684]
# cat.2198.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2409.jpg
# 1/1 [==============================] - 0s 11ms/step
# [4.6845557e-12]
# cat.2409.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2071.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.27102274]
# cat.2071.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2225.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.84683996]
# cat.2225.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2011.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00085575]
# cat.2011.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2308.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.2715947e-07]
# cat.2308.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2019.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.21529272]
# cat.2019.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2234.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.6684344]
# cat.2234.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2124.jpg
# 1/1 [==============================] - 0s 11ms/step
# [3.907999e-07]
# cat.2124.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2104.jpg
# 1/1 [==============================] - 0s 11ms/step
# [4.486064e-06]
# cat.2104.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2403.jpg
# 1/1 [==============================] - 0s 11ms/step
# [3.8175145e-07]
# cat.2403.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2181.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.0194602e-12]
# cat.2181.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2113.jpg
# 1/1 [==============================] - 0s 11ms/step
# [3.0488466e-11]
# cat.2113.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2385.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.8612554]
# cat.2385.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2070.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.09888595]
# cat.2070.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2275.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.01063217]
# cat.2275.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2474.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.03392802]
# cat.2474.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2259.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.3147557e-08]
# cat.2259.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2290.jpg
# 1/1 [==============================] - 0s 11ms/step
# [7.83347e-10]
# cat.2290.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2316.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.7041991]
# cat.2316.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2323.jpg
# 1/1 [==============================] - 0s 11ms/step
# [2.3485913e-05]
# cat.2323.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2476.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.99692637]
# cat.2476.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2095.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00035355]
# cat.2095.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2467.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.86450595]
# cat.2467.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2301.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.99999976]
# cat.2301.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2455.jpg
# 1/1 [==============================] - 0s 11ms/step
# [5.415481e-09]
# cat.2455.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2321.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.03481963]
# cat.2321.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2024.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00088811]
# cat.2024.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2268.jpg
# 1/1 [==============================] - 0s 11ms/step
# [5.7128716e-22]
# cat.2268.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2213.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.735511]
# cat.2213.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2085.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.99593]
# cat.2085.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2130.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.53506213]
# cat.2130.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2498.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.7953879]
# cat.2498.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2462.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.7556693e-09]
# cat.2462.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2122.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.02343536]
# cat.2122.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2027.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00082532]
# cat.2027.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2441.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.3544703]
# cat.2441.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2369.jpg
# 1/1 [==============================] - 0s 11ms/step
# [3.1204574e-11]
# cat.2369.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2443.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.04550803]
# cat.2443.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2382.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.03001023]
# cat.2382.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2376.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.29989073]
# cat.2376.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2313.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.7329165e-05]
# cat.2313.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2433.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.7284187]
# cat.2433.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2299.jpg
# 1/1 [==============================] - 0s 12ms/step
# [8.9303765e-05]
# cat.2299.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2180.jpg
# 1/1 [==============================] - 0s 11ms/step
# [7.664857e-05]
# cat.2180.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2156.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.40522957]
# cat.2156.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2442.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.9991353]
# cat.2442.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2142.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.8317157e-06]
# cat.2142.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2347.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.3194917e-11]
# cat.2347.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2384.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.9236689]
# cat.2384.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2200.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.04988798]
# cat.2200.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2396.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.00196465]
# cat.2396.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2244.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.8557236]
# cat.2244.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2139.jpg
# 1/1 [==============================] - 0s 11ms/step
# [7.836589e-11]
# cat.2139.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2304.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00028842]
# cat.2304.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2421.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.9583809]
# cat.2421.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2463.jpg
# 1/1 [==============================] - 0s 11ms/step
# [4.6612496e-07]
# cat.2463.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2220.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.02508564]
# cat.2220.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2114.jpg
# 1/1 [==============================] - 0s 11ms/step
# [4.7351145e-06]
# cat.2114.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2038.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.99999774]
# cat.2038.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2229.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.7683207]
# cat.2229.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2057.jpg
# 1/1 [==============================] - 0s 10ms/step
# [5.8397734e-07]
# cat.2057.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2006.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.]
# cat.2006.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2196.jpg
# 1/1 [==============================] - 0s 11ms/step
# [2.3210944e-08]
# cat.2196.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2408.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.80556625]
# cat.2408.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2280.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.06517591]
# cat.2280.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2303.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.16329938]
# cat.2303.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2475.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.6689048]
# cat.2475.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2125.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.01455245]
# cat.2125.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2110.jpg
# 1/1 [==============================] - 0s 11ms/step
# [2.1197389e-08]
# cat.2110.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2236.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.295849]
# cat.2236.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2107.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00171102]
# cat.2107.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2191.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00014621]
# cat.2191.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2399.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.9999932]
# cat.2399.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2001.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.12170445]
# cat.2001.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2049.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00044186]
# cat.2049.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2203.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.02187271]
# cat.2203.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2242.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.00799607]
# cat.2242.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2199.jpg
# 1/1 [==============================] - 0s 10ms/step
# [1.8128121e-07]
# cat.2199.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2315.jpg
# 1/1 [==============================] - 0s 10ms/step
# [8.149683e-07]
# cat.2315.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2417.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.9992292]
# cat.2417.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2320.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.99701774]
# cat.2320.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2215.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.8508277]
# cat.2215.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2249.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00167355]
# cat.2249.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2477.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00214782]
# cat.2477.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2287.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.9946576e-21]
# cat.2287.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2291.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00265117]
# cat.2291.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2048.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.02016091]
# cat.2048.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2178.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.13784558]
# cat.2178.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2128.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00113707]
# cat.2128.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2414.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.]
# cat.2414.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2432.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.0908858]
# cat.2432.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2459.jpg
# 1/1 [==============================] - 0s 11ms/step
# [3.9161114e-05]
# cat.2459.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2168.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.05906123]
# cat.2168.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2380.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.87905616]
# cat.2380.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2440.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.0204891]
# cat.2440.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2186.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.01217863]
# cat.2186.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2005.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.3758923e-09]
# cat.2005.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2386.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.95674574]
# cat.2386.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2435.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00536199]
# cat.2435.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2356.jpg
# 1/1 [==============================] - 0s 11ms/step
# [8.113585e-08]
# cat.2356.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2140.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.6599179]
# cat.2140.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2412.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00014413]
# cat.2412.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2238.jpg
# 1/1 [==============================] - 0s 11ms/step
# [7.111835e-05]
# cat.2238.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2353.jpg
# 1/1 [==============================] - 0s 11ms/step
# [8.3529245e-05]
# cat.2353.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2101.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.19509727]
# cat.2101.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2465.jpg
# 1/1 [==============================] - 0s 11ms/step
# [5.472423e-06]
# cat.2465.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2357.jpg
# ...
# [1.3226075e-09]
# cat.2456.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2464.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.7905177]
# cat.2464.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2430.jpg
# 1/1 [==============================] - 0s 11ms/step
# [4.7136307e-08]
# cat.2430.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2007.jpg
# 1/1 [==============================] - 0s 11ms/step
# [4.2453343e-05]
# cat.2007.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2297.jpg
# 1/1 [==============================] - 0s 11ms/step
# [2.9123381e-05]
# cat.2297.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2147.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.2420493]
# cat.2147.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2293.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.01293492]
# cat.2293.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2233.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00087427]
# cat.2233.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2206.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.03032366]
# cat.2206.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2264.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.9965905]
# cat.2264.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2381.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.00250791]
# cat.2381.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2251.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.20405984]
# cat.2251.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2329.jpg
# 1/1 [==============================] - 0s 11ms/step
# [4.9618643e-07]
# cat.2329.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2119.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.06972518]
# cat.2119.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2406.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00192921]
# cat.2406.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2013.jpg
# 1/1 [==============================] - 0s 10ms/step
# [5.2514497e-07]
# cat.2013.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2209.jpg
# 1/1 [==============================] - 0s 10ms/step
# [2.2839386e-05]
# cat.2209.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2358.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.95462143]
# cat.2358.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2393.jpg
# 1/1 [==============================] - 0s 10ms/step
# [1.1988967e-06]
# cat.2393.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2480.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.02360248]
# cat.2480.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2087.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.7307893e-05]
# cat.2087.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2424.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.04368404]
# cat.2424.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2083.jpg
# 1/1 [==============================] - 0s 11ms/step
# [4.4596797e-07]
# cat.2083.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2438.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.0117214]
# cat.2438.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2224.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.5238396e-13]
# cat.2224.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2486.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.01815528]
# cat.2486.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2416.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.02056678]
# cat.2416.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2025.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.97988796]
# cat.2025.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2325.jpg
# 1/1 [==============================] - 0s 11ms/step
# [7.4843665e-06]
# cat.2325.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2088.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.617289]
# cat.2088.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2263.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.10428288]
# cat.2263.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2079.jpg
# 1/1 [==============================] - 0s 10ms/step
# [4.4157263e-05]
# cat.2079.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2326.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.00101672]
# cat.2326.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2331.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.06987067]
# cat.2331.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2292.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.9055556e-11]
# cat.2292.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2482.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.12547337]
# cat.2482.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2434.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.78180844]
# cat.2434.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2084.jpg
# 1/1 [==============================] - 0s 11ms/step
# [2.1838165e-05]
# cat.2084.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2269.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.8820617]
# cat.2269.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2109.jpg
# 1/1 [==============================] - 0s 11ms/step
# [2.715631e-05]
# cat.2109.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2478.jpg
# 1/1 [==============================] - 0s 11ms/step
# [9.747299e-07]
# cat.2478.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2055.jpg
# 1/1 [==============================] - 0s 11ms/step
# [4.139429e-05]
# cat.2055.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2171.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00176143]
# cat.2171.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2254.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00084227]
# cat.2254.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2447.jpg
# 1/1 [==============================] - 0s 11ms/step
# [7.469358e-05]
# cat.2447.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2279.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.5491963e-08]
# cat.2279.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2428.jpg
# 1/1 [==============================] - 0s 11ms/step
# [2.4960448e-06]
# cat.2428.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2047.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.10578976]
# cat.2047.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2252.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00391605]
# cat.2252.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2134.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.09246641]
# cat.2134.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2016.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.09263641]
# cat.2016.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2418.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.07318746]
# cat.2418.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2012.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.19853124]
# cat.2012.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2246.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00125419]
# cat.2246.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2354.jpg
# 1/1 [==============================] - 0s 11ms/step
# [5.422289e-10]
# cat.2354.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2437.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.00129395]
# cat.2437.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2064.jpg
# 1/1 [==============================] - 0s 11ms/step
# [2.4923128e-09]
# cat.2064.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2471.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00101078]
# cat.2471.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2458.jpg
# 1/1 [==============================] - 0s 10ms/step
# [3.312114e-10]
# cat.2458.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2328.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00092506]
# cat.2328.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2436.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.99396884]
# cat.2436.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2151.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.9509907]
# cat.2151.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2067.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.03276561]
# cat.2067.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2487.jpg
# 1/1 [==============================] - 0s 11ms/step
# [4.3770015e-07]
# cat.2487.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2194.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00566763]
# cat.2194.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2253.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.4321138]
# cat.2253.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2307.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.6413973]
# cat.2307.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2054.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.03850969]
# cat.2054.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2322.jpg
# 1/1 [==============================] - 0s 10ms/step
# [5.4016233e-05]
# cat.2322.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2120.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.91801447]
# cat.2120.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2074.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.94655555]
# cat.2074.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2273.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.37598005]
# cat.2273.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2148.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.00156972]
# cat.2148.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2282.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.0138305]
# cat.2282.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2068.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.5480878e-06]
# cat.2068.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2117.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.02911274]
# cat.2117.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2155.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.99999845]
# cat.2155.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2218.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00011946]
# cat.2218.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2219.jpg
# 1/1 [==============================] - 0s 11ms/step
# [4.402208e-13]
# cat.2219.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2423.jpg
# 1/1 [==============================] - 0s 11ms/step
# [5.7147525e-05]
# cat.2423.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2305.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.7756098]
# cat.2305.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2137.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.869967e-12]
# cat.2137.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2089.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00011764]
# cat.2089.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2330.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.94477946]
# cat.2330.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2160.jpg
# 1/1 [==============================] - 0s 11ms/step
# [6.1835614e-10]
# cat.2160.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2232.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.9830598]
# cat.2232.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2034.jpg
# 1/1 [==============================] - 0s 11ms/step
# [4.3785787e-12]
# cat.2034.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2073.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.04717172]
# cat.2073.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2296.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00058168]
# cat.2296.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2348.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.70976996]
# cat.2348.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2361.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.9844067e-07]
# cat.2361.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2112.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.8036255e-06]
# cat.2112.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2053.jpg
# 1/1 [==============================] - 0s 11ms/step
# [2.5735515e-06]
# cat.2053.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2310.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.59931463]
# cat.2310.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2411.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.6379071]
# cat.2411.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2255.jpg
# 1/1 [==============================] - 0s 11ms/step
# [3.2679836e-08]
# cat.2255.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2227.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.000178]
# cat.2227.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2121.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.8406255e-06]
# cat.2121.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2132.jpg
# 1/1 [==============================] - 0s 11ms/step
# [2.0978588e-07]
# cat.2132.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2445.jpg
# 1/1 [==============================] - 0s 11ms/step
# [7.281075e-16]
# cat.2445.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2174.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.16590954]
# cat.2174.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2135.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00350879]
# cat.2135.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2491.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.99364257]
# cat.2491.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2333.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00669754]
# cat.2333.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2076.jpg
# 1/1 [==============================] - 0s 10ms/step
# [1.0990477e-08]
# cat.2076.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2010.jpg
# 1/1 [==============================] - 0s 10ms/step
# [1.6264732e-06]
# cat.2010.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2175.jpg
# 1/1 [==============================] - 0s 11ms/step
# [0.00063468]
# cat.2175.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2188.jpg
# 1/1 [==============================] - 0s 11ms/step
# [1.4549162e-08]
# cat.2188.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2003.jpg
# 1/1 [==============================] - 0s 10ms/step
# [2.1203007e-12]
# cat.2003.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2383.jpg
# 1/1 [==============================] - 0s 10ms/step
# [7.2662565e-09]
# cat.2383.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2337.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.08149523]
# cat.2337.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2051.jpg
# 1/1 [==============================] - 0s 10ms/step
# [0.9394445]
# cat.2051.jpg is a dog
#
# cats_and_dogs_filtered/validation/cats/cat.2334.jpg
# 1/1 [==============================] - 0s 11ms/step
# [5.817106e-12]
# cat.2334.jpg is a cat
#
# cats_and_dogs_filtered/validation/cats/cat.2240.jpg
# 1/1 [==============================] - 0s 10ms/step
# [9.1874095e-12]
# cat.2240.jpg is a cat

# %% [markdown]
# ### Visualizing Intermediate Representations
#
# To get a feel for what kind of features your CNN has learned, one fun thing to do is to visualize how an input gets transformed as it goes through the model.
#
# You can pick a random image from the training set, and then generate a figure where each row is the output of a layer, and each image in the row is a specific filter in that output feature map. Rerun this cell to generate intermediate representations for a variety of training images.

# %%
import numpy as np
import random
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# Define a new Model that will take an image as input, and will output
# intermediate representations for all layers in the previous model
successive_outputs = [layer.output for layer in model.layers]
visualization_model = tf.keras.models.Model(inputs = model.input, outputs = successive_outputs)

# Prepare a random input image from the training set.
cat_img_files = [os.path.join(train_cats_dir, f) for f in train_cat_fnames]
dog_img_files = [os.path.join(train_dogs_dir, f) for f in train_dog_fnames]
img_path = random.choice(cat_img_files + dog_img_files)
img = load_img(img_path, target_size=(150, 150))  # this is a PIL image
x   = img_to_array(img)                           # Numpy array with shape (150, 150, 3)
x   = x.reshape((1,) + x.shape)                   # Numpy array with shape (1, 150, 150, 3)

# Scale by 1/255
x /= 255.0

# Run the image through the network, thus obtaining all
# intermediate representations for this image.
successive_feature_maps = visualization_model.predict(x)

# These are the names of the layers, so you can have them as part of our plot
layer_names = [layer.name for layer in model.layers]

# Display the representations
for layer_name, feature_map in zip(layer_names, successive_feature_maps):
  
  if len(feature_map.shape) == 4:
    
    #-------------------------------------------
    # Just do this for the conv / maxpool layers, not the fully-connected layers
    #-------------------------------------------
    n_features = feature_map.shape[-1]  # number of features in the feature map
    size       = feature_map.shape[ 1]  # feature map shape (1, size, size, n_features)
    
    # Tile the images in this matrix
    display_grid = np.zeros((size, size * n_features))
    
    #-------------------------------------------------
    # Postprocess the feature to be visually palatable
    #-------------------------------------------------
    for i in range(n_features):
      x  = feature_map[0, :, :, i]
      x -= x.mean()
      x /= x.std ()
      x *=  64
      x += 128
      x  = np.clip(x, 0, 255).astype('uint8')
      display_grid[:, i * size : (i + 1) * size] = x # Tile each filter into a horizontal grid

    #-----------------
    # Display the grid
    #-----------------
    scale = 20. / n_features
    plt.figure( figsize=(scale * n_features, scale) )
    plt.title ( layer_name )
    plt.grid  ( False )
    plt.imshow( display_grid, aspect='auto', cmap='viridis' )
# Out:
# 1/1 [==============================] - 0s 48ms/step
# /tmp/ipykernel_34226/1822312938.py:48: RuntimeWarning: invalid value encountered in divide
#   x /= x.std ()

# %% [markdown]
# You can see above how the pixels highlighted turn to increasingly abstract and compact representations, especially at the bottom grid.
#
# The representations downstream start highlighting what the network pays attention to, and they show fewer and fewer features being "activated"; most are set to zero. This is called _representation sparsity_ and is a key feature of deep learning. These representations carry increasingly less information about the original pixels of the image, but increasingly refined information about the class of the image. You can think of a convnet (or a deep network in general) as an information distillation pipeline wherein each layer filters out the most useful features.

# %% [markdown]
# ### Evaluating Accuracy and Loss for the Model
#
# You will plot the training/validation accuracy and loss as collected during training:

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot  ( epochs,     acc , label='Training' )
plt.plot  ( epochs, val_acc , label='Validation' )
plt.title ('Training and validation accuracy')
plt.legend()
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot  ( epochs,     loss , label='Training' )
plt.plot  ( epochs, val_loss , label='Validation' )
plt.legend()
plt.title ('Training and validation loss'   )
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %% [markdown]
# As you can see, the model is **overfitting** like it's getting out of fashion. The training accuracy (in blue) gets close to 100% while the validation accuracy (in orange) stalls as 70%. The validation loss reaches its minimum after only five epochs.
#
# Since you have a relatively small number of training examples (2000), overfitting should be the number one concern. Overfitting happens when a model exposed to too few examples learns patterns that do not generalize to new data, i.e. when the model starts using irrelevant features for making predictions. For instance, if you, as a human, only see three images of people who are lumberjacks, and three images of people who are sailors, and among them the only person wearing a cap is a lumberjack, you might start thinking that wearing a cap is a sign of being a lumberjack as opposed to a sailor. You would then make a pretty lousy lumberjack/sailor classifier.
#
# Overfitting is the central problem in machine learning: given that you are fitting the parameters of our model to a given dataset, how can you make sure that the representations learned by the model will be applicable to data it has never seen before? How do you avoid learning things that are specific to the training data?
#
# In the next exercise, you'll look at ways to prevent overfitting in this classification model.

# %% [markdown]
# ## Clean Up
#
# Before running the next exercise, run the following cell to terminate the kernel and free memory resources:

# %%
import os, signal

os.kill(     os.getpid() , 
         signal.SIGKILL
       )
